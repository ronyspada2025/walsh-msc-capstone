# %% [markdown]
# # 03 — Exploratory Data Analysis
#
# Distributions, missingness, and the correlation/multicollinearity check among socioeconomic and infrastructure predictors (see Analytic Approach, step 1).

# %%
import sys, pathlib
sys.path.append(str(pathlib.Path.cwd().parent))
import pandas as pd
import numpy as np
from src import data_loader as dl
pd.set_option('display.max_columns', 60)

# %%
from src import visualization_utils as viz
merged = pd.read_csv(dl.PROCESSED_DIR / 'merged_municipal_dataset.csv')
merged.describe(include='all').T.head(30)
# Out:
#                               count unique                         top  freq  \
# MUNICIP_ID                  10107.0    NaN                         NaN   NaN
# NOME                          10106   5570  Alta Floresta D'Oeste - RO     2
# PIB_MIL_REAIS               10106.0    NaN                         NaN   NaN
# POP_2024                    10106.0    NaN                         NaN   NaN
# V93_populacao residente     10106.0    NaN                         NaN   NaN
# V6318_area da unidade terr  10106.0    NaN                         NaN   NaN
# V614_densidade demografic   10106.0    NaN                         NaN   NaN
# UF                            10106     27                          MG  1495
# GDP_PER_CAP                 10106.0    NaN                         NaN   NaN
# ACC_CDMA_IS_95              10106.0    NaN                         NaN   NaN
# ACC_GSM                     10106.0    NaN                         NaN   NaN
# ...

# %% [markdown]
# ## Correlation matrix (multicollinearity screen for RQ1/RQ3)

# %%
# num_cols = ['POP_DENSITY','GDP_PER_CAP','GDP_AGRO_VA','GDP_IND_VA',
#             'TECH_4G_CNT','TECH_5G_SA_CNT','SPECTRUM_DENSITY',
#             'OPERATOR_SHARE','PROVIDER_CNT']
# viz.correlation_heatmap(merged, num_cols)

# %% [markdown]
# ## Distributions and regional patterns

# %%
# merged.hist(figsize=(14, 10), bins=40);
